# %% [markdown]
# <a href="https://colab.research.google.com/github/praveenpankaj/WildFireBurntAreaMapping/blob/main/Palisades_Forest_Fire_Burn_Severity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Palisades Fire
# The Palisades Fire was first reported on January 7, 2025 at 10:30AM.
#
# **Date Started**
# 01/07/2025 10:30 AM
#
# **Location:** 34.1144,-118.55334
#
# **References:**
#
# [1] Earth Fire Alliance https://www.earthfirealliance.org/
#
# [2] Caldor Fire: https://en.wikipedia.org/wiki/Caldor_Fire
#
# [3] FIRMS dataset API access: https://firms.modaps.eosdis.nasa.gov/content/academy/data_api/firms_api_use.html
#
# [4] Available Datasets: https://docs.google.com/spreadsheets/d/1hChsmwXMYNinFXaCx4SGFEfcPZ0v7MFW4xBobAnBd5w/edit?gid=0#gid=0

# %% [markdown]
# ## Near Real-Time Data Available from FIRMS

# %%
from google.colab import userdata
MAP_KEY = userdata.get('FIRMS_key')

# %%
#check number of transactions
import pandas as pd
url = 'https://firms.modaps.eosdis.nasa.gov/mapserver/mapkey_status/?MAP_KEY=' + MAP_KEY
try:
  df = pd.read_json(url,  typ='series')
  display(df)
except:
  # possible error, wrong MAP_KEY value, check for extra quotes, missing letters
  print ("There is an issue with the query. \nTry in your browser: %s" % url)
# Out:
# transaction_limit             5000
# current_transactions             0
# transaction_interval    10 minutes
# dtype: object

# %%
def get_transaction_count() :
  count = 0
  try:
    df = pd.read_json(url,  typ='series')
    count = df['current_transactions']
  except:
    print ("Error in our call.")
  return count

tcount = get_transaction_count()
print ('The current FIRMS data transaction count is %i' % tcount)
# Out:
# The current FIRMS data transaction count is 0

# %%
da_url = 'https://firms.modaps.eosdis.nasa.gov/api/data_availability/csv/' + MAP_KEY + '/all'
df = pd.read_csv(da_url)
display(df)
# Out:
#             data_id    min_date    max_date
# 0         MODIS_NRT  2024-08-01  2025-02-17
# 1          MODIS_SP  2000-11-01  2024-07-31
# 2  VIIRS_NOAA20_NRT  2019-12-04  2025-02-17
# 3  VIIRS_NOAA21_NRT  2024-01-17  2025-02-17
# 4    VIIRS_SNPP_NRT  2024-12-01  2025-02-17
# 5     VIIRS_SNPP_SP  2012-01-20  2024-11-30
# 6       LANDSAT_NRT  2022-06-20  2025-02-16
# 7          GOES_NRT  2022-08-09  2025-02-17
# 8          BA_MODIS  2000-11-01  2024-10-01

# %% [markdown]
# MODIS_NRT: Modis Near Real Time Data (MODIS data products available through LANCE include land surface temperature, land surface reflectance, radiances, clouds/aerosols, water vapor, active fire, snow cover, and sea ice)
#
# LANDSAT_NRT: Landsat Near Real Time Data is available within 12 hours of acquisition. Uses are to monitor land disturbances, which can increase carbon emissions and cause environmental impacts and to detect fires and thermal anomalies

# %%
# !pip install geopandas --quiet
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
area_url = 'https://firms.modaps.eosdis.nasa.gov/api/area/csv/' + MAP_KEY + '/VIIRS_NOAA20_NRT/-118.55,34.10/10/2025-01-01'
df_area = pd.read_csv(area_url, sep=',', on_bad_lines='skip', engine='python')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
df_area.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Empty DataFrame
# Columns: [Invalid area. Expects: [west, south, east, north].]
# Index: []

# %%
try:
    import geemap, ee
except ModuleNotFoundError:
  print("Package not installed. pip in Google Colab.")
  # !pip install geemap --quiet
  import geemap, ee

# %%
import pandas as pd
from shapely import wkt
import geopandas as gpd
import colorcet as cc
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
try:
        ee.Initialize(project='ee-praveenpankaj')

except Exception as e:
        ee.Authenticate()
        ee.Initialize(project='ee-praveenpankaj')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
loc_coords = ee.Geometry.Point([-118.55666, 34.08939])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
countries = ee.FeatureCollection("FAO/GAUL/2015/level0").select('ADM0_NAME')

# Filter the feature collection to subset France.
us = countries.filter(ee.Filter.eq('ADM0_NAME', 'United States of America'))

states = ee.FeatureCollection("FAO/GAUL/2015/level1")
state_aoi = states.filter(ee.Filter.eq('ADM1_NAME', 'California'))

counties = ee.FeatureCollection("FAO/GAUL/2015/level2")
county_aoi = counties.filter(ee.Filter.eq('ADM2_NAME', 'Los Angeles'))

# %%
M = geemap.Map()
M.add_basemap("HYBRID")
M.addLayer(us, {}, "USA")
M.addLayer(state_aoi, {}, 'California')
M.addLayer(county_aoi, {'color': 'red'}, 'Los Angeles County')
M.centerObject(ee_object=loc_coords, zoom=15)

#M.centerObject(ee_object = county_aoi, zoom=15)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
M
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[34.009409000000005, -118.31729500000003], controls=(WidgetControl(options=['position', 'transparen…

# %%
countries = ee.FeatureCollection("FAO/GAUL/2015/level2")

filtered_countries = countries.filter(ee.Filter.stringStartsWith('ADM2_NAME', 'Los'))
unique_names = filtered_countries.reduceColumns(
    reducer=ee.Reducer.frequencyHistogram(),
    selectors=['ADM2_NAME']
).get('histogram').getInfo()

# Print the number of features found (optional)
print(f'Number of features with ADM_1) starting with "Los": {len(unique_names)}')

# Get the number of features
num_features = len(unique_names)

print(unique_names)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Number of features with ADM_1) starting with "Los": 30
# {'Los Alamos': 1, 'Los Aldamas': 1, 'Los Amates': 1, 'Los Andes': 4, 'Los Angeles': 1, 'Los Arabos': 1, 'Los Cacaos': 1, 'Los Cedrales': 1, 'Los Chiles': 1, 'Los Cordobas': 1, 'Los Herreros': 1, 'Los Hidalgos': 1, 'Los Lagos': 1, 'Los Llanos': 1, 'Los Palacios': 1, 'Los Palmitos': 1, 'Los Patios': 1, 'Los Pozos': 1, 'Los Ramones': 1, 'Los Reyes': 2, 'Los Reyes De Juarez': 1, 'Los R¡os': 1, 'Los Salias': 1, 'Los Santos': 2, 'Los Tanques': 1, 'Losice': 1, 'Loska Dolina': 1, 'Loski Potok': 1, 'Lospalos': 1, 'Losuia': 1}

# %%
# Burn Area Index Calculation
def calc_bais(image):
    return ee.Image(image.expression(
    '(1 - ((R2*R4*R4)/(R4))**(0.5))*((SWIR2 - R4)/((SWIR2 + R4)**(0.5)) + 1)', {
      'RED': image.select('B4'),
      'R2': image.select('B6'),
      'R3': image.select('B7'),
      'SWIR2': image.select('B12'),
      'R4': image.select('B8A'),
}))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# **Short wave infrared (SWIR)** measurements can help scientists estimate how much water is present in plants and soil, as water absorbs SWIR wavelengths. Short wave infrared bands (a band is a region of the electromagnetic spectrum; a satellite sensor can image Earth in different bands) are also useful for distinguishing between cloud types (water clouds versus ice clouds), snow and ice, all of which appear white in visible light. In this composite vegetation appears in shades of green, soils and built-up areas are in various shades of brown, and water appears black. Newly burned land reflects strongly in SWIR bands, making them valuable for mapping fire damages. Each rock type reflects shortwave infrared light differently, making it possible to map out geology by comparing reflected SWIR light.
#
# For Sentinel-2 SWIR composite: (B12, B8A, B04)

# %% [markdown]
# ### Sentinel-2 data visualization

# %%
def maskS2clouds(image):
    qa = image.select('QA60');

    # Bits 10 and 11 are clouds and cirrus, respectively.
    cloudBitMask = 1 << 10
    cirrusBitMask = 1 << 11

    # Both flags should be set to zero, indicating clear conditions.
    mask = qa.bitwiseAnd(cloudBitMask).eq(0) and qa.bitwiseAnd(cirrusBitMask).eq(0)

    return image.updateMask(mask).divide(10000)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# prompt: in the code below filter imagecollection for cloud using ee.Filter.eq 'CLOUD_COVER'

# Assuming you have an ImageCollection named 'imageCollection'
# Replace 'imageCollection' with the actual name of your ImageCollection

def maskS2clouds(image):
    qa = image.select('QA60')

    # Bits 10 and 11 are clouds and cirrus, respectively.
    cloudBitMask = 1 << 10
    cirrusBitMask = 1 << 11

    # Both flags should be set to zero, indicating clear conditions.
    mask = qa.bitwiseAnd(cloudBitMask).eq(0) and qa.bitwiseAnd(cirrusBitMask).eq(0)

    return image.updateMask(mask).divide(10000)

# Filter the ImageCollection for cloud cover
filtered_imageCollection = imageCollection.filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 10)) # Example: Cloud cover less than 10%

#Alternatively, if you have a 'CLOUD_COVER' property:
#filtered_imageCollection = imageCollection.filter(ee.Filter.lt('CLOUD_COVER', 10))


# Now 'filtered_imageCollection' contains only images with less than 10% cloud cover.
# You can then apply other functions like map to process the images.
# For example:
# masked_collection = filtered_imageCollection.map(maskS2clouds)

# %%
# Sentinel-2 image filtered
# Sentinel-2 acquisition plan: https://sentinel.esa.int/web/sentinel/missions/sentinel-2/acquisition-plans
# Predict their passes: http://www.satflare.com/track.asp?q=40697#LIST
# https://www.researchgate.net/post/How_can_I_know_when_Sentinel-2_passes_over_a_location

se2_bb = ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED').filterDate(
    '2024-11-01', '2024-12-30').filterBounds(county_aoi)

se2_ab = ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED').filterDate(
    '2025-01-12', '2025-02-17'). \
    filterBounds(county_aoi). \
    filter(ee.Filter.lte('CLOUDY_PIXEL_PERCENTAGE', 10))

#rgb_bands = ['B4', 'B3', 'B2']
swir_rgb = ['B12', 'B8A', 'B4']

# set some thresholds
# Sentinel-2 Composites: https://github.com/sentinel-hub/custom-scripts/tree/master/sentinel-2/composites
#rgbViz = {"min":0.0, "max": 0.3, "bands": rgb_bands}
swirgbViz = {"min": 0.0, "max": 0.4, "bands": swir_rgb}
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
M.addLayer(se2_bb.median().divide(10000).clip(county_aoi), swirgbViz, 'Before Fire')
M.addLayer(se2_ab.median().divide(10000).clip(county_aoi), swirgbViz, 'After Fire')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
M
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(bottom=418933.0, center=[34.06830277687429, -118.54969024658205], controls=(WidgetControl(options=['positi…

# %% [markdown]
# # NBR Calculation
#
# Reference: https://colab.research.google.com/drive/1GUbBRdlXsq1szNoX5tS_LMAHakkXNdzL?usp=sharing#scrollTo=Qb5Ekvr6jWpo

# %%
bais_after = se2_ab.map(maskS2clouds).map(calc_bais)
bais_before = se2_bb.map(maskS2clouds).map(calc_bais)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
delta_bais = bais_after.mosaic().subtract(bais_before.mosaic())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
delta_bais = delta_bais.multiply(1000)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
thresholds = ee.Image([-1000, -251, -101, 99, 269, 439, 659, 2000]);
bais_class = delta_bais.lt(thresholds).reduce('sum').toInt()
labels = ['NA', 'High Severity', 'Moderate-high Severity',
          'Moderate-low Severity', 'Low Severity','Unburned',
          'Enhanced Regrowth, Low', 'Enhanced Regrowth, High']
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
M.addLayer(delta_bais.clip(county_aoi),
             {'min': 0, 'max': 500, 'palette': ['red', 'black']},
              'Difference Burnt Area')
cpalette = ['7a8737', 'acbe4d', '0ae042', 'fff70b', 'ffaf38', 'ff641b', 'a41fd6', 'ffffff'];

M.addLayer(bais_class.clip(county_aoi), {'palette': cpalette}, 'Burn Severity')
M.addLayerControl()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
visualization = {
  'min': 100,
  'max': 700,
  'palette': cc.fire
}
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
loc_coords.coordinates().getInfo()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# [-118.55666, 34.08939]

# %%
# initialize our map
Map = geemap.Map()
Map.add_basemap("SATELLITE")
Map.add_marker(loc_coords.coordinates().getInfo(), title = 'Palisades Fire Origin')
Map.addLayer(delta_bais.clip(county_aoi), visualization, 'Burnt Area')
Map.centerObject(ee_object=loc_coords, zoom=15)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[34.089389999999995, -118.55666000000002], controls=(WidgetControl(options=['position', 'transparen…

# %% [markdown]
# The FDC algorithm provides a “fire mask code” for each pixel, with a few dozen predefined values. Here we focus on the following code values: processed fire pixel (value 10), saturated fire pixel (11), cloud contaminated fire pixel (12), high probability fire pixel (13), medium probability fire pixel (14), low probability fire pixel (15); and the corresponding “temporally filtered” code values: temporally filtered process fire pixel (30), temporally filtered saturated fire pixel (31), etc. These mask codes (10–15 and 30–35) indicate that the pixel is believed to cover a wildfire, with a varying degree of confidence.

# %%
# !pip install segment-geospatial pycrs

# %%
from samgeo import SamGeo
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
bbox = Map.user_roi_coords()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
geemap.ee_to_geotiff(
    se2_ab, "swir.tif", bbox, zoom=17, vis_params={"bands": ['B12', 'B8A', 'B4']}
    )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Downloaded image 1/21384
# Downloaded image 2/21384
# Downloaded image 3/21384
# Downloaded image 4/21384
# Downloaded image 5/21384
# Downloaded image 6/21384
# Downloaded image 7/21384
# Downloaded image 8/21384
# Downloaded image 9/21384
# Downloaded image 10/21384
# Downloaded image 11/21384
# Downloaded image 12/21384
# Downloaded image 13/21384
# Downloaded image 14/21384
# Downloaded image 15/21384
# Downloaded image 16/21384
# Downloaded image 17/21384
# Downloaded image 18/21384
# Downloaded image 19/21384
# Downloaded image 20/21384
# Downloaded image 21/21384
# Downloaded image 22/21384
# Downloaded image 23/21384
# Downloaded image 24/21384
# Downloaded image 25/21384
# Downloaded image 26/21384
# Downloaded image 27/21384
# Downloaded image 28/21384
# Downloaded image 29/21384
# Downloaded image 30/21384
# Downloaded image 31/21384
# Downloaded image 32/21384
# Downloaded image 33/21384
# Downloaded image 34/21384
# Downloaded image 35/21384
# Downloaded image 36/21384
# Downloaded image 37/21384
# Downloaded image 38/21384
# Downloaded image 39/21384
# Downloaded image 40/21384
# Downloaded image 41/21384
# Downloaded image 42/21384
# Downloaded image 43/21384
# Downloaded image 44/21384
# Downloaded image 45/21384
# Downloaded image 46/21384
# Downloaded image 47/21384
# Downloaded image 48/21384
# Downloaded image 49/21384
# Downloaded image 50/21384
# Downloaded image 51/21384
# Downloaded image 52/21384
# Downloaded image 53/21384
# Downloaded image 54/21384
# Downloaded image 55/21384
# Downloaded image 56/21384
# Downloaded image 57/21384
# Downloaded image 58/21384
# Downloaded image 59/21384
# Downloaded image 60/21384
# Downloaded image 61/21384
# Downloaded image 62/21384
# Downloaded image 63/21384
# Downloaded image 64/21384
# Downloaded image 65/21384
# Downloaded image 66/21384
# Downloaded image 67/21384
# Downloaded image 68/21384
# Downloaded image 69/21384
# Downloaded image 70/21384
# Downloaded image 71/21384
# Downloaded image 72/21384
# Downloaded image 73/21384
# Downloaded image 74/21384
# Downloaded image 75/21384
# Downloaded image 76/21384
# Downloaded image 77/21384
# Downloaded image 78/21384
# Downloaded image 79/21384
# Downloaded image 80/21384
# Downloaded image 81/21384
# Downloaded image 82/21384
# Downloaded image 83/21384
# Downloaded image 84/21384
# Downloaded image 85/21384
# Downloaded image 86/21384
# Downloaded image 87/21384
# Downloaded image 88/21384
# Downloaded image 89/21384
# Downloaded image 90/21384
# Downloaded image 91/21384
# Downloaded image 92/21384
# Downloaded image 93/21384
# Downloaded image 94/21384
# Downloaded image 95/21384
# Downloaded image 96/21384
# Downloaded image 97/21384
# Downloaded image 98/21384
# Downloaded image 99/21384
# Downloaded image 100/21384
# Downloaded image 101/21384
# Downloaded image 102/21384
# Downloaded image 103/21384
# Downloaded image 104/21384
# Downloaded image 105/21384
# Downloaded image 106/21384
# Downloaded image 107/21384
# Downloaded image 108/21384
# Downloaded image 109/21384
# Downloaded image 110/21384
# Downloaded image 111/21384
# Downloaded image 112/21384
# Downloaded image 113/21384
# Downloaded image 114/21384
# Downloaded image 115/21384
# Downloaded image 116/21384
# Downloaded image 117/21384
# Downloaded image 118/21384
# Downloaded image 119/21384
# Downloaded image 120/21384
# Downloaded image 121/21384
# Downloaded image 122/21384
# Downloaded image 123/21384
# Downloaded image 124/21384
# Downloaded image 125/21384
# Downloaded image 126/21384
# Downloaded image 127/21384
# Downloaded image 128/21384
# Downloaded image 129/21384
# Downloaded image 130/21384
# Downloaded image 131/21384
# Downloaded image 132/21384
# Downloaded image 133/21384
# Downloaded image 134/21384
# Downloaded image 135/21384
# Downloaded image 136/21384
# Downloaded image 137/21384
# Downloaded image 138/21384
# Downloaded image 139/21384
# Downloaded image 140/21384
# Downloaded image 141/21384
# Downloaded image 142/21384
# Downloaded image 143/21384
# Downloaded image 144/21384
# Downloaded image 145/21384
# Downloaded image 146/21384
# Downloaded image 147/21384
# Downloaded image 148/21384
# Downloaded image 149/21384
# Downloaded image 150/21384
# Downloaded image 151/21384
# Downloaded image 152/21384
# Downloaded image 153/21384
# Downloaded image 154/21384
# Downloaded image 155/21384
# Downloaded image 156/21384
# Downloaded image 157/21384
# Downloaded image 158/21384
# Downloaded image 159/21384
# Downloaded image 160/21384
# Downloaded image 161/21384
# Downloaded image 162/21384
# Downloaded image 163/21384
# Downloaded image 164/21384
# Downloaded image 165/21384
# Downloaded image 166/21384
# Downloaded image 167/21384
# Downloaded image 168/21384
# Downloaded image 169/21384
# Downloaded image 170/21384
# Downloaded image 171/21384
# Downloaded image 172/21384
# Downloaded image 173/21384
# Downloaded image 174/21384
# Downloaded image 175/21384
# Downloaded image 176/21384
# Downloaded image 177/21384
# Downloaded image 178/21384
# Downloaded image 179/21384
# Downloaded image 180/21384
# Downloaded image 181/21384
# Downloaded image 182/21384
# Downloaded image 183/21384
# Downloaded image 184/21384
# Downloaded image 185/21384
# Downloaded image 186/21384
# Downloaded image 187/21384
# Downloaded image 188/21384
# Downloaded image 189/21384
# Downloaded image 190/21384
# Downloaded image 191/21384
# Downloaded image 192/21384
# Downloaded image 193/21384
# Downloaded image 194/21384
# Downloaded image 195/21384
# Downloaded image 196/21384
# Downloaded image 197/21384
# Downloaded image 198/21384
# Downloaded image 199/21384
# Downloaded image 200/21384
# Downloaded image 201/21384
# Downloaded image 202/21384
# Downloaded image 203/21384
# Downloaded image 204/21384
# Downloaded image 205/21384
# Downloaded image 206/21384
# Downloaded image 207/21384
# Downloaded image 208/21384
# Downloaded image 209/21384
# Downloaded image 210/21384
# Downloaded image 211/21384
# Downloaded image 212/21384
# Downloaded image 213/21384
# Downloaded image 214/21384
# Downloaded image 215/21384
# Downloaded image 216/21384
# Downloaded image 217/21384
# Downloaded image 218/21384
# Downloaded image 219/21384
# Downloaded image 220/21384
# Downloaded image 221/21384
# Downloaded image 222/21384
# Downloaded image 223/21384
# Downloaded image 224/21384
# Downloaded image 225/21384
# Downloaded image 226/21384
# Downloaded image 227/21384
# Downloaded image 228/21384
# Downloaded image 229/21384
# Downloaded image 230/21384
# Downloaded image 231/21384
# Downloaded image 232/21384
# Downloaded image 233/21384
# Downloaded image 234/21384
# Downloaded image 235/21384
# Downloaded image 236/21384
# Downloaded image 237/21384
# Downloaded image 238/21384
# Downloaded image 239/21384
# Downloaded image 240/21384
# Downloaded image 241/21384
# Downloaded image 242/21384
# Downloaded image 243/21384
# Downloaded image 244/21384
# Downloaded image 245/21384
# Downloaded image 246/21384
# Downloaded image 247/21384
# Downloaded image 248/21384
# Downloaded image 249/21384
# Downloaded image 250/21384
# Downloaded image 251/21384
# Downloaded image 252/21384
# Downloaded image 253/21384
# Downloaded image 254/21384
# Downloaded image 255/21384
# Downloaded image 256/21384
# Downloaded image 257/21384
# Downloaded image 258/21384
# Downloaded image 259/21384
# Downloaded image 260/21384
# Downloaded image 261/21384
# Downloaded image 262/21384
# Downloaded image 263/21384
# Downloaded image 264/21384
# Downloaded image 265/21384
# Downloaded image 266/21384
# Downloaded image 267/21384
# Downloaded image 268/21384
# Downloaded image 269/21384
# Downloaded image 270/21384
# Downloaded image 271/21384
# Downloaded image 272/21384
# Downloaded image 273/21384
# Downloaded image 274/21384
# Downloaded image 275/21384
# Downloaded image 276/21384
# Downloaded image 277/21384
# Downloaded image 278/21384
# Downloaded image 279/21384
# Downloaded image 280/21384
# Downloaded image 281/21384
# Downloaded image 282/21384
# Downloaded image 283/21384
# Downloaded image 284/21384
# Downloaded image 285/21384
# Downloaded image 286/21384
# Downloaded image 287/21384
# Downloaded image 288/21384
# Downloaded image 289/21384
# Downloaded image 290/21384
# Downloaded image 291/21384
# Downloaded image 292/21384
# Downloaded image 293/21384
# Downloaded image 294/21384
# Downloaded image 295/21384
# Downloaded image 296/21384
# Downloaded image 297/21384
# Downloaded image 298/21384
# Downloaded image 299/21384
# Downloaded image 300/21384
# Downloaded image 301/21384
# Downloaded image 302/21384
# Downloaded image 303/21384
# Downloaded image 304/21384
# Downloaded image 305/21384
# Downloaded image 306/21384
# Downloaded image 307/21384
# Downloaded image 308/21384
# Downloaded image 309/21384
# Downloaded image 310/21384
# Downloaded image 311/21384
# Downloaded image 312/21384
# Downloaded image 313/21384
# Downloaded image 314/21384
# Downloaded image 315/21384
# Downloaded image 316/21384
# Downloaded image 317/21384
# Downloaded image 318/21384
# Downloaded image 319/21384
# Downloaded image 320/21384
# Downloaded image 321/21384
# Downloaded image 322/21384
# Downloaded image 323/21384
# Downloaded image 324/21384
# Downloaded image 325/21384
# Downloaded image 326/21384
# Downloaded image 327/21384
# Downloaded image 328/21384
# Downloaded image 329/21384
# Downloaded image 330/21384
# Downloaded image 331/21384
# Downloaded image 332/21384
# Downloaded image 333/21384
# Downloaded image 334/21384
# Downloaded image 335/21384
# Downloaded image 336/21384
# Downloaded image 337/21384
# Downloaded image 338/21384
# Downloaded image 339/21384
# Downloaded image 340/21384
# Downloaded image 341/21384
# Downloaded image 342/21384
# Downloaded image 343/21384
# Downloaded image 344/21384
# Downloaded image 345/21384
# Downloaded image 346/21384
# Downloaded image 347/21384
# Downloaded image 348/21384
# Downloaded image 349/21384
# Downloaded image 350/21384
# Downloaded image 351/21384
# Downloaded image 352/21384
# Downloaded image 353/21384
# Downloaded image 354/21384
# Downloaded image 355/21384
# Downloaded image 356/21384
# Downloaded image 357/21384
# Downloaded image 358/21384
# Downloaded image 359/21384
# Downloaded image 360/21384
# Downloaded image 361/21384
# Downloaded image 362/21384
# Downloaded image 363/21384
# Downloaded image 364/21384
# Downloaded image 365/21384
# Downloaded image 366/21384
# Downloaded image 367/21384
# Downloaded image 368/21384
# Downloaded image 369/21384
# Downloaded image 370/21384
# Downloaded image 371/21384
# Downloaded image 372/21384
# Downloaded image 373/21384
# Downloaded image 374/21384
# Downloaded image 375/21384
# Downloaded image 376/21384
# Downloaded image 377/21384
# Downloaded image 378/21384
# Downloaded image 379/21384
# Downloaded image 380/21384
# Downloaded image 381/21384
# Downloaded image 382/21384
# Downloaded image 383/21384
# Downloaded image 384/21384
# Downloaded image 385/21384
# Downloaded image 386/21384
# Downloaded image 387/21384
# Downloaded image 388/21384
# Downloaded image 389/21384
# Downloaded image 390/21384
# Downloaded image 391/21384
# Downloaded image 392/21384
# Downloaded image 393/21384
# Downloaded image 394/21384
# Downloaded image 395/21384
# Downloaded image 396/21384
# Downloaded image 397/21384
# Downloaded image 398/21384
# Downloaded image 399/21384
# Downloaded image 400/21384
# Downloaded image 401/21384
# Downloaded image 402/21384
# Downloaded image 403/21384
# Downloaded image 404/21384
# Downloaded image 405/21384
# Downloaded image 406/21384
# Downloaded image 407/21384
# Downloaded image 408/21384
# Downloaded image 409/21384
# Downloaded image 410/21384
# Downloaded image 411/21384
# Downloaded image 412/21384
# Downloaded image 413/21384
# Downloaded image 414/21384
# Downloaded image 415/21384
# Downloaded image 416/21384
# Downloaded image 417/21384
# Downloaded image 418/21384
# Downloaded image 419/21384
# Downloaded image 420/21384
# Downloaded image 421/21384
# Downloaded image 422/21384
# Downloaded image 423/21384
# Downloaded image 424/21384
# Downloaded image 425/21384
# Downloaded image 426/21384
# Downloaded image 427/21384
# Downloaded image 428/21384
# Downloaded image 429/21384
# Downloaded image 430/21384
# Downloaded image 431/21384
# Downloaded image 432/21384
# Downloaded image 433/21384
# Downloaded image 434/21384
# Downloaded image 435/21384
# Downloaded image 436/21384
# Downloaded image 437/21384
# Downloaded image 438/21384
# Downloaded image 439/21384
# Downloaded image 440/21384
# Downloaded image 441/21384
# Downloaded image 442/21384
# Downloaded image 443/21384
# Downloaded image 444/21384
# Downloaded image 445/21384
# Downloaded image 446/21384
# Downloaded image 447/21384
# Downloaded image 448/21384
# Downloaded image 449/21384
# Downloaded image 450/21384
# Downloaded image 451/21384
# Downloaded image 452/21384
# Downloaded image 453/21384
# Downloaded image 454/21384
# Downloaded image 455/21384
# Downloaded image 456/21384
# Downloaded image 457/21384
# Downloaded image 458/21384
# Downloaded image 459/21384
# Downloaded image 460/21384
# Downloaded image 461/21384
# Downloaded image 462/21384
# Downloaded image 463/21384
# Downloaded image 464/21384
# Downloaded image 465/21384
# Downloaded image 466/21384
# Downloaded image 467/21384
# Downloaded image 468/21384
# Downloaded image 469/21384
# Downloaded image 470/21384
# Downloaded image 471/21384
# Downloaded image 472/21384
# Downloaded image 473/21384
# Downloaded image 474/21384
# Downloaded image 475/21384
# Downloaded image 476/21384
# Downloaded image 477/21384
# Downloaded image 478/21384
# Downloaded image 479/21384
# Downloaded image 480/21384
# Downloaded image 481/21384
# Downloaded image 482/21384
# Downloaded image 483/21384
# Downloaded image 484/21384
# Downloaded image 485/21384
# Downloaded image 486/21384
# Downloaded image 487/21384
# Downloaded image 488/21384
# Downloaded image 489/21384
# Downloaded image 490/21384
# Downloaded image 491/21384
# Downloaded image 492/21384
# Downloaded image 493/21384
# Downloaded image 494/21384
# Downloaded image 495/21384
# Downloaded image 496/21384
# Downloaded image 497/21384
# Downloaded image 498/21384
# Downloaded image 499/21384
# Downloaded image 500/21384
# Downloaded image 501/21384
# Downloaded image 502/21384
# Downloaded image 503/21384
# Downloaded image 504/21384
# Downloaded image 505/21384
# Downloaded image 506/21384
# Downloaded image 507/21384
# Downloaded image 508/21384
# Downloaded image 509/21384
# Downloaded image 510/21384
# Downloaded image 511/21384
# Downloaded image 512/21384
# Downloaded image 513/21384
# Downloaded image 514/21384
# Downloaded image 515/21384
# Downloaded image 516/21384
# Downloaded image 517/21384
# Downloaded image 518/21384
# Downloaded image 519/21384
# Downloaded image 520/21384
# Downloaded image 521/21384
# Downloaded image 522/21384
# Downloaded image 523/21384
# Downloaded image 524/21384
# Downloaded image 525/21384
# Downloaded image 526/21384
# Downloaded image 527/21384
# Downloaded image 528/21384
# Downloaded image 529/21384
# Downloaded image 530/21384
# Downloaded image 531/21384
# Downloaded image 532/21384
# Downloaded image 533/21384
# Downloaded image 534/21384
# Downloaded image 535/21384
# Downloaded image 536/21384
# Downloaded image 537/21384
# Downloaded image 538/21384
# Downloaded image 539/21384
# Downloaded image 540/21384
# Downloaded image 541/21384
# Downloaded image 542/21384
# Downloaded image 543/21384
# Downloaded image 544/21384
# Downloaded image 545/21384
# Downloaded image 546/21384
# Downloaded image 547/21384
# Downloaded image 548/21384
# Downloaded image 549/21384
# Downloaded image 550/21384
# Downloaded image 551/21384
# Downloaded image 552/21384
# Downloaded image 553/21384
# Downloaded image 554/21384
# Downloaded image 555/21384
# Downloaded image 556/21384
# Downloaded image 557/21384
# Downloaded image 558/21384
# Downloaded image 559/21384
# Downloaded image 560/21384
# Downloaded image 561/21384
# Downloaded image 562/21384
# Downloaded image 563/21384
# Downloaded image 564/21384
# Downloaded image 565/21384
# Downloaded image 566/21384
# Downloaded image 567/21384
# Downloaded image 568/21384
# Downloaded image 569/21384
# Downloaded image 570/21384
# Downloaded image 571/21384
# Downloaded image 572/21384
# Downloaded image 573/21384
# Downloaded image 574/21384
# Downloaded image 575/21384
# Downloaded image 576/21384
# Downloaded image 577/21384
# Downloaded image 578/21384
# Downloaded image 579/21384
# Downloaded image 580/21384
# Downloaded image 581/21384
# Downloaded image 582/21384
# Downloaded image 583/21384
# Downloaded image 584/21384
# Downloaded image 585/21384
# Downloaded image 586/21384
# Downloaded image 587/21384
# Downloaded image 588/21384
# Downloaded image 589/21384
# Downloaded image 590/21384
# Downloaded image 591/21384
# Downloaded image 592/21384
# Downloaded image 593/21384
# Downloaded image 594/21384
# Downloaded image 595/21384
# Downloaded image 596/21384
# Downloaded image 597/21384
# Downloaded image 598/21384
# Downloaded image 599/21384
# Downloaded image 600/21384
# Downloaded image 601/21384
# Downloaded image 602/21384
# Downloaded image 603/21384
# Downloaded image 604/21384
# Downloaded image 605/21384
# Downloaded image 606/21384
# Downloaded image 607/21384
# Downloaded image 608/21384
# Downloaded image 609/21384
# Downloaded image 610/21384
# Downloaded image 611/21384
# Downloaded image 612/21384
# Downloaded image 613/21384
# Downloaded image 614/21384
# Downloaded image 615/21384
# Downloaded image 616/21384
# Downloaded image 617/21384
# Downloaded image 618/21384
# Downloaded image 619/21384
# Downloaded image 620/21384
# Downloaded image 621/21384
# Downloaded image 622/21384
# Downloaded image 623/21384
# Downloaded image 624/21384
# Downloaded image 625/21384
# Downloaded image 626/21384
# Downloaded image 627/21384
# Downloaded image 628/21384
# Downloaded image 629/21384
# Downloaded image 630/21384
# Downloaded image 631/21384
# Downloaded image 632/21384
# Downloaded image 633/21384
# Downloaded image 634/21384
# Downloaded image 635/21384
# Downloaded image 636/21384
# Downloaded image 637/21384
# Downloaded image 638/21384
# Downloaded image 639/21384
# Downloaded image 640/21384
# Downloaded image 641/21384
# Downloaded image 642/21384
# Downloaded image 643/21384
# Downloaded image 644/21384
# Downloaded image 645/21384
# Downloaded image 646/21384
# Downloaded image 647/21384
# Downloaded image 648/21384
# Downloaded image 649/21384
# Downloaded image 650/21384
# Downloaded image 651/21384
# Downloaded image 652/21384
# Downloaded image 653/21384
# Downloaded image 654/21384
# Downloaded image 655/21384
# Downloaded image 656/21384
# Downloaded image 657/21384
# Downloaded image 658/21384
# Downloaded image 659/21384
# Downloaded image 660/21384
# Downloaded image 661/21384
# Downloaded image 662/21384
# Downloaded image 663/21384
# Downloaded image 664/21384
# Downloaded image 665/21384
# Downloaded image 666/21384
# Downloaded image 667/21384
# Downloaded image 668/21384
# Downloaded image 669/21384
# Downloaded image 670/21384
# Downloaded image 671/21384
# Downloaded image 672/21384
# Downloaded image 673/21384
# Downloaded image 674/21384
# Downloaded image 675/21384
# Downloaded image 676/21384
# Downloaded image 677/21384
# Downloaded image 678/21384
# Downloaded image 679/21384
# Downloaded image 680/21384
# Downloaded image 681/21384
# Downloaded image 682/21384
# Downloaded image 683/21384
# Downloaded image 684/21384
# Downloaded image 685/21384
# Downloaded image 686/21384
# Downloaded image 687/21384
# Downloaded image 688/21384
# Downloaded image 689/21384
# Downloaded image 690/21384
# Downloaded image 691/21384
# Downloaded image 692/21384
# Downloaded image 693/21384
# Downloaded image 694/21384
# Downloaded image 695/21384
# Downloaded image 696/21384
# Downloaded image 697/21384
# Downloaded image 698/21384
# Downloaded image 699/21384
# Downloaded image 700/21384
# Downloaded image 701/21384
# Downloaded image 702/21384
# Downloaded image 703/21384
# Downloaded image 704/21384
# Downloaded image 705/21384
# Downloaded image 706/21384
# Downloaded image 707/21384
# Downloaded image 708/21384
# Downloaded image 709/21384
# Downloaded image 710/21384
# Downloaded image 711/21384
# Downloaded image 712/21384
# Downloaded image 713/21384
# Downloaded image 714/21384
# Downloaded image 715/21384
# Downloaded image 716/21384
# Downloaded image 717/21384
# Downloaded image 718/21384
# Downloaded image 719/21384
# Downloaded image 720/21384
# Downloaded image 721/21384
# Downloaded image 722/21384
# Downloaded image 723/21384
# Downloaded image 724/21384
# Downloaded image 725/21384
# Downloaded image 726/21384
# Downloaded image 727/21384
# Downloaded image 728/21384
# Downloaded image 729/21384
# Downloaded image 730/21384
# Downloaded image 731/21384
# Downloaded image 732/21384
# Downloaded image 733/21384
# Downloaded image 734/21384
# Downloaded image 735/21384
# Downloaded image 736/21384
# Downloaded image 737/21384
# Downloaded image 738/21384
# Downloaded image 739/21384
# Downloaded image 740/21384
# Downloaded image 741/21384
# Downloaded image 742/21384
# Downloaded image 743/21384
# Downloaded image 744/21384
# Downloaded image 745/21384
# Downloaded image 746/21384
# Downloaded image 747/21384
# Downloaded image 748/21384
# Downloaded image 749/21384
# Downloaded image 750/21384
# Downloaded image 751/21384
# Downloaded image 752/21384
# Downloaded image 753/21384
# Downloaded image 754/21384
# Downloaded image 755/21384
# Downloaded image 756/21384
# Downloaded image 757/21384
# Downloaded image 758/21384
# Downloaded image 759/21384
# Downloaded image 760/21384
# Downloaded image 761/21384
# Downloaded image 762/21384
# Downloaded image 763/21384
# Downloaded image 764/21384
# Downloaded image 765/21384
# Downloaded image 766/21384
# Downloaded image 767/21384
# Downloaded image 768/21384
# Downloaded image 769/21384
# Downloaded image 770/21384
# Downloaded image 771/21384
# Downloaded image 772/21384
# Downloaded image 773/21384
# Downloaded image 774/21384
# Downloaded image 775/21384
# Downloaded image 776/21384
# Downloaded image 777/21384
# Downloaded image 778/21384
# Downloaded image 779/21384
# Downloaded image 780/21384
# Downloaded image 781/21384
# Downloaded image 782/21384
# Downloaded image 783/21384
# Downloaded image 784/21384
# Downloaded image 785/21384
# Downloaded image 786/21384
# Downloaded image 787/21384
# Downloaded image 788/21384
# Downloaded image 789/21384
# Downloaded image 790/21384
# Downloaded image 791/21384
# Downloaded image 792/21384
# Downloaded image 793/21384
# Downloaded image 794/21384
# Downloaded image 795/21384
# Downloaded image 796/21384
# Downloaded image 797/21384
# Downloaded image 798/21384
# Downloaded image 799/21384
# Downloaded image 800/21384
# Downloaded image 801/21384
# Downloaded image 802/21384
# Downloaded image 803/21384
# Downloaded image 804/21384
# Downloaded image 805/21384
# Downloaded image 806/21384
# Downloaded image 807/21384
# Downloaded image 808/21384
# Downloaded image 809/21384
# Downloaded image 810/21384
# Downloaded image 811/21384
# Downloaded image 812/21384
# Downloaded image 813/21384
# Downloaded image 814/21384
# Downloaded image 815/21384
# Downloaded image 816/21384
# Downloaded image 817/21384
# Downloaded image 818/21384
# Downloaded image 819/21384
# Downloaded image 820/21384
# Downloaded image 821/21384
# Downloaded image 822/21384
# Downloaded image 823/21384
# Downloaded image 824/21384
# Downloaded image 825/21384
# Downloaded image 826/21384
# Downloaded image 827/21384
# Downloaded image 828/21384
# Downloaded image 829/21384
# Downloaded image 830/21384
# Downloaded image 831/21384
# Downloaded image 832/21384
# Downloaded image 833/21384
# Downloaded image 834/21384
# Downloaded image 835/21384
# Downloaded image 836/21384
# Downloaded image 837/21384
# Downloaded image 838/21384
# Downloaded image 839/21384
# Downloaded image 840/21384
# Downloaded image 841/21384
# Downloaded image 842/21384
# Downloaded image 843/21384
# Downloaded image 844/21384
# Downloaded image 845/21384
# Downloaded image 846/21384
# Downloaded image 847/21384
# Downloaded image 848/21384
# Downloaded image 849/21384
# Downloaded image 850/21384
# Downloaded image 851/21384
# Downloaded image 852/21384
# Downloaded image 853/21384
# Downloaded image 854/21384
# Downloaded image 855/21384
# Downloaded image 856/21384
# Downloaded image 857/21384
# Downloaded image 858/21384
# Downloaded image 859/21384
# Downloaded image 860/21384
# Downloaded image 861/21384
# Downloaded image 862/21384
# Downloaded image 863/21384
# Downloaded image 864/21384
# Downloaded image 865/21384
# Downloaded image 866/21384
# Downloaded image 867/21384
# Downloaded image 868/21384
# Downloaded image 869/21384
# Downloaded image 870/21384
# Downloaded image 871/21384
# Downloaded image 872/21384
# Downloaded image 873/21384
# Downloaded image 874/21384
# Downloaded image 875/21384
# Downloaded image 876/21384
# Downloaded image 877/21384
# Downloaded image 878/21384
# Downloaded image 879/21384
# Downloaded image 880/21384
# Downloaded image 881/21384
# Downloaded image 882/21384
# Downloaded image 883/21384
# Downloaded image 884/21384
# Downloaded image 885/21384
# Downloaded image 886/21384
# Downloaded image 887/21384
# Downloaded image 888/21384
# Downloaded image 889/21384
# Downloaded image 890/21384
# Downloaded image 891/21384
# Downloaded image 892/21384
# Downloaded image 893/21384
# Downloaded image 894/21384
# Downloaded image 895/21384
# Downloaded image 896/21384
# Downloaded image 897/21384
# Downloaded image 898/21384
# Downloaded image 899/21384
# Downloaded image 900/21384
# Downloaded image 901/21384
# Downloaded image 902/21384
# Downloaded image 903/21384
# Downloaded image 904/21384
# Downloaded image 905/21384
# Downloaded image 906/21384
# Downloaded image 907/21384
# Downloaded image 908/21384
# Downloaded image 909/21384
# Downloaded image 910/21384
# Downloaded image 911/21384
# Downloaded image 912/21384
# Downloaded image 913/21384
# Downloaded image 914/21384
# Downloaded image 915/21384
# Downloaded image 916/21384
# Downloaded image 917/21384
# Downloaded image 918/21384
# Downloaded image 919/21384
# Downloaded image 920/21384
# Downloaded image 921/21384
# Downloaded image 922/21384
# Downloaded image 923/21384
# Downloaded image 924/21384
# Downloaded image 925/21384
# Downloaded image 926/21384
# Downloaded image 927/21384
# Downloaded image 928/21384
# Downloaded image 929/21384
# Downloaded image 930/21384
# Downloaded image 931/21384
# Downloaded image 932/21384
# Downloaded image 933/21384
# Downloaded image 934/21384
# Downloaded image 935/21384
# Downloaded image 936/21384
# Downloaded image 937/21384
# Downloaded image 938/21384
# Downloaded image 939/21384
# Downloaded image 940/21384
# Downloaded image 941/21384
# Downloaded image 942/21384
# Downloaded image 943/21384
# Downloaded image 944/21384
# Downloaded image 945/21384
# Downloaded image 946/21384
# Downloaded image 947/21384
# Downloaded image 948/21384
# Downloaded image 949/21384
# Downloaded image 950/21384
# Downloaded image 951/21384
# Downloaded image 952/21384
# Downloaded image 953/21384
# Downloaded image 954/21384
# Downloaded image 955/21384
# Downloaded image 956/21384
# Downloaded image 957/21384
# Downloaded image 958/21384
# Downloaded image 959/21384
# Downloaded image 960/21384
# Downloaded image 961/21384
# Downloaded image 962/21384
# Downloaded image 963/21384
# Downloaded image 964/21384
# Downloaded image 965/21384
# Downloaded image 966/21384
# Downloaded image 967/21384
# Downloaded image 968/21384
# Downloaded image 969/21384
# Downloaded image 970/21384
# Downloaded image 971/21384
# Downloaded image 972/21384
# Downloaded image 973/21384
# Downloaded image 974/21384
# Downloaded image 975/21384
# Downloaded image 976/21384
# Downloaded image 977/21384
# Downloaded image 978/21384
# Downloaded image 979/21384
# Downloaded image 980/21384
# Downloaded image 981/21384
# Downloaded image 982/21384
# Downloaded image 983/21384
# Downloaded image 984/21384
# Downloaded image 985/21384
# Downloaded image 986/21384
# Downloaded image 987/21384
# Downloaded image 988/21384
# Downloaded image 989/21384
# Downloaded image 990/21384
# Downloaded image 991/21384
# Downloaded image 992/21384
# Downloaded image 993/21384
# Downloaded image 994/21384
# Downloaded image 995/21384
# Downloaded image 996/21384
# Downloaded image 997/21384
# Downloaded image 998/21384
# Downloaded image 999/21384
# Downloaded image 1000/21384
# Downloaded image 1001/21384
# Downloaded image 1002/21384
# Downloaded image 1003/21384
# Downloaded image 1004/21384
# Downloaded image 1005/21384
# Downloaded image 1006/21384
# Downloaded image 1007/21384
# Downloaded image 1008/21384
# Downloaded image 1009/21384
# Downloaded image 1010/21384
# Downloaded image 1011/21384
# Downloaded image 1012/21384
# Downloaded image 1013/21384
# Downloaded image 1014/21384
# Downloaded image 1015/21384
# Downloaded image 1016/21384
# Downloaded image 1017/21384
# Downloaded image 1018/21384
# Downloaded image 1019/21384
# Downloaded image 1020/21384
# Downloaded image 1021/21384
# Downloaded image 1022/21384
# Downloaded image 1023/21384
# Downloaded image 1024/21384
# Downloaded image 1025/21384
# Downloaded image 1026/21384
# Downloaded image 1027/21384
# Downloaded image 1028/21384
# Downloaded image 1029/21384
# Downloaded image 1030/21384
# Downloaded image 1031/21384
# Downloaded image 1032/21384
# Downloaded image 1033/21384
# Downloaded image 1034/21384
# Downloaded image 1035/21384
# Downloaded image 1036/21384
# Downloaded image 1037/21384
# Downloaded image 1038/21384
# Downloaded image 1039/21384
# Downloaded image 1040/21384
# Downloaded image 1041/21384
# Downloaded image 1042/21384
# Downloaded image 1043/21384
# Downloaded image 1044/21384
# Downloaded image 1045/21384
# Downloaded image 1046/21384
# Downloaded image 1047/21384
# Downloaded image 1048/21384
# Downloaded image 1049/21384
# Downloaded image 1050/21384
# Downloaded image 1051/21384
# Downloaded image 1052/21384
# Downloaded image 1053/21384
# Downloaded image 1054/21384
# Downloaded image 1055/21384
# Downloaded image 1056/21384
# Downloaded image 1057/21384
# Downloaded image 1058/21384
# Downloaded image 1059/21384
# Downloaded image 1060/21384
# Downloaded image 1061/21384
# Downloaded image 1062/21384
# Downloaded image 1063/21384
# Downloaded image 1064/21384
# Downloaded image 1065/21384
# Downloaded image 1066/21384
# Downloaded image 1067/21384
# Downloaded image 1068/21384
# Downloaded image 1069/21384
# Downloaded image 1070/21384
# Downloaded image 1071/21384
# Downloaded image 1072/21384
# Downloaded image 1073/21384
# Downloaded image 1074/21384
# Downloaded image 1075/21384
# Downloaded image 1076/21384
# Downloaded image 1077/21384
# Downloaded image 1078/21384
# Downloaded image 1079/21384
# Downloaded image 1080/21384
# Downloaded image 1081/21384
# Downloaded image 1082/21384
# Downloaded image 1083/21384
# Downloaded image 1084/21384
# Downloaded image 1085/21384
# Downloaded image 1086/21384
# Downloaded image 1087/21384
# Downloaded image 1088/21384
# Downloaded image 1089/21384
# Downloaded image 1090/21384
# Downloaded image 1091/21384
# Downloaded image 1092/21384
# Downloaded image 1093/21384
# Downloaded image 1094/21384
# Downloaded image 1095/21384
# Downloaded image 1096/21384
# Downloaded image 1097/21384
# Downloaded image 1098/21384
# Downloaded image 1099/21384
# Downloaded image 1100/21384
# Downloaded image 1101/21384
# Downloaded image 1102/21384
# Downloaded image 1103/21384
# Downloaded image 1104/21384
# Downloaded image 1105/21384
# Downloaded image 1106/21384
# Downloaded image 1107/21384
# Downloaded image 1108/21384
# Downloaded image 1109/21384
# Downloaded image 1110/21384
# Downloaded image 1111/21384
# Downloaded image 1112/21384
# Downloaded image 1113/21384
# Downloaded image 1114/21384
# Downloaded image 1115/21384
# Downloaded image 1116/21384
# Downloaded image 1117/21384
# Downloaded image 1118/21384
# Downloaded image 1119/21384
# Downloaded image 1120/21384
# Downloaded image 1121/21384
# Downloaded image 1122/21384
# Downloaded image 1123/21384
# Downloaded image 1124/21384
# Downloaded image 1125/21384
# Downloaded image 1126/21384
# Downloaded image 1127/21384
# Downloaded image 1128/21384
# Downloaded image 1129/21384
# Downloaded image 1130/21384
# Downloaded image 1131/21384
# Downloaded image 1132/21384
# Downloaded image 1133/21384
# Downloaded image 1134/21384
# Downloaded image 1135/21384
# Downloaded image 1136/21384
# Downloaded image 1137/21384
# Downloaded image 1138/21384
# Downloaded image 1139/21384
# Downloaded image 1140/21384
# Downloaded image 1141/21384
# Downloaded image 1142/21384
# Downloaded image 1143/21384
# Downloaded image 1144/21384
# Downloaded image 1145/21384
# Downloaded image 1146/21384
# Downloaded image 1147/21384
# Downloaded image 1148/21384
# Downloaded image 1149/21384
# Downloaded image 1150/21384
# Downloaded image 1151/21384
# Downloaded image 1152/21384
# Downloaded image 1153/21384
# Downloaded image 1154/21384
# Downloaded image 1155/21384
# Downloaded image 1156/21384
# Downloaded image 1157/21384
# Downloaded image 1158/21384
# Downloaded image 1159/21384
# Downloaded image 1160/21384
# Downloaded image 1161/21384
# Downloaded image 1162/21384
# Downloaded image 1163/21384
# Downloaded image 1164/21384
# Downloaded image 1165/21384
# Downloaded image 1166/21384
# Downloaded image 1167/21384
# Downloaded image 1168/21384
# Downloaded image 1169/21384
# Downloaded image 1170/21384
# Downloaded image 1171/21384
# Downloaded image 1172/21384
# Downloaded image 1173/21384
# Downloaded image 1174/21384
# Downloaded image 1175/21384
# Downloaded image 1176/21384
# Downloaded image 1177/21384
# Downloaded image 1178/21384
# Downloaded image 1179/21384
# Downloaded image 1180/21384
# Downloaded image 1181/21384
# Downloaded image 1182/21384
# Downloaded image 1183/21384
# Downloaded image 1184/21384
# Downloaded image 1185/21384
# Downloaded image 1186/21384
# Downloaded image 1187/21384
# Downloaded image 1188/21384
# Downloaded image 1189/21384
# Downloaded image 1190/21384
# Downloaded image 1191/21384
# Downloaded image 1192/21384
# Downloaded image 1193/21384
# Downloaded image 1194/21384
# Downloaded image 1195/21384
# Downloaded image 1196/21384
# Downloaded image 1197/21384
# Downloaded image 1198/21384
# Downloaded image 1199/21384
# Downloaded image 1200/21384
# Downloaded image 1201/21384
# Downloaded image 1202/21384
# Downloaded image 1203/21384
# Downloaded image 1204/21384
# Downloaded image 1205/21384
# Downloaded image 1206/21384
# Downloaded image 1207/21384
# Downloaded image 1208/21384
# Downloaded image 1209/21384
# Downloaded image 1210/21384
# Downloaded image 1211/21384
# Downloaded image 1212/21384
# Downloaded image 1213/21384
# Downloaded image 1214/21384
# Downloaded image 1215/21384
# Downloaded image 1216/21384
# Downloaded image 1217/21384
# Downloaded image 1218/21384
# Downloaded image 1219/21384
# Downloaded image 1220/21384
# Downloaded image 1221/21384
# Downloaded image 1222/21384
# Downloaded image 1223/21384
# Downloaded image 1224/21384
# Downloaded image 1225/21384
# Downloaded image 1226/21384
# Downloaded image 1227/21384
# Downloaded image 1228/21384
# Downloaded image 1229/21384
# Downloaded image 1230/21384
# Downloaded image 1231/21384
# Downloaded image 1232/21384
# Downloaded image 1233/21384
# Downloaded image 1234/21384
# Downloaded image 1235/21384
# Downloaded image 1236/21384
# Downloaded image 1237/21384
# Downloaded image 1238/21384
# Downloaded image 1239/21384
# Downloaded image 1240/21384
# Downloaded image 1241/21384
# Downloaded image 1242/21384
# Downloaded image 1243/21384
# Downloaded image 1244/21384
# Downloaded image 1245/21384
# Downloaded image 1246/21384
# Downloaded image 1247/21384
# Downloaded image 1248/21384
# Downloaded image 1249/21384
# Downloaded image 1250/21384
# Downloaded image 1251/21384
# Downloaded image 1252/21384
# Downloaded image 1253/21384
# Downloaded image 1254/21384
# Downloaded image 1255/21384
# Downloaded image 1256/21384
# Downloaded image 1257/21384
# Downloaded image 1258/21384
# Downloaded image 1259/21384
# Downloaded image 1260/21384
# Downloaded image 1261/21384
# Downloaded image 1262/21384
# Downloaded image 1263/21384
# Downloaded image 1264/21384
# Downloaded image 1265/21384
# Downloaded image 1266/21384
# Downloaded image 1267/21384
# Downloaded image 1268/21384
# Downloaded image 1269/21384
# Downloaded image 1270/21384
# Downloaded image 1271/21384
# Downloaded image 1272/21384
# Downloaded image 1273/21384
# Downloaded image 1274/21384
# Downloaded image 1275/21384
# Downloaded image 1276/21384
# Downloaded image 1277/21384
# Downloaded image 1278/21384
# Downloaded image 1279/21384
# Downloaded image 1280/21384
# Downloaded image 1281/21384
# Downloaded image 1282/21384
# Downloaded image 1283/21384
# Downloaded image 1284/21384
# Downloaded image 1285/21384
# Downloaded image 1286/21384
# Downloaded image 1287/21384
# Downloaded image 1288/21384
# Downloaded image 1289/21384
# Downloaded image 1290/21384
# Downloaded image 1291/21384
# Downloaded image 1292/21384
# Downloaded image 1293/21384
# Downloaded image 1294/21384
# Downloaded image 1295/21384
# Downloaded image 1296/21384
# Downloaded image 1297/21384
# Downloaded image 1298/21384
# Downloaded image 1299/21384
# Downloaded image 1300/21384
# Downloaded image 1301/21384
# Downloaded image 1302/21384
# Downloaded image 1303/21384
# Downloaded image 1304/21384
# Downloaded image 1305/21384
# Downloaded image 1306/21384
# Downloaded image 1307/21384
# Downloaded image 1308/21384
# Downloaded image 1309/21384
# Downloaded image 1310/21384
# Downloaded image 1311/21384
# Downloaded image 1312/21384
# Downloaded image 1313/21384
# Downloaded image 1314/21384
# Downloaded image 1315/21384
# Downloaded image 1316/21384
# Downloaded image 1317/21384
# Downloaded image 1318/21384
# Downloaded image 1319/21384
# Downloaded image 1320/21384
# Downloaded image 1321/21384
# Downloaded image 1322/21384
# Downloaded image 1323/21384
# Downloaded image 1324/21384
# Downloaded image 1325/21384
# Downloaded image 1326/21384
# Downloaded image 1327/21384
# Downloaded image 1328/21384
# Downloaded image 1329/21384
# Downloaded image 1330/21384
# Downloaded image 1331/21384
# Downloaded image 1332/21384
# Downloaded image 1333/21384
# Downloaded image 1334/21384
# Downloaded image 1335/21384
# Downloaded image 1336/21384
# Downloaded image 1337/21384
# Downloaded image 1338/21384
# Downloaded image 1339/21384
# Downloaded image 1340/21384
# Downloaded image 1341/21384
# Downloaded image 1342/21384
# Downloaded image 1343/21384
# Downloaded image 1344/21384
# Downloaded image 1345/21384
# Downloaded image 1346/21384
# Downloaded image 1347/21384
# Downloaded image 1348/21384
# Downloaded image 1349/21384
# Downloaded image 1350/21384
# Downloaded image 1351/21384
# Downloaded image 1352/21384
# Downloaded image 1353/21384
# Downloaded image 1354/21384
# Downloaded image 1355/21384
# Downloaded image 1356/21384
# Downloaded image 1357/21384
# Downloaded image 1358/21384
# Downloaded image 1359/21384
# Downloaded image 1360/21384
# Downloaded image 1361/21384
# Downloaded image 1362/21384
# Downloaded image 1363/21384
# Downloaded image 1364/21384
# Downloaded image 1365/21384
# Downloaded image 1366/21384
# Downloaded image 1367/21384
# Downloaded image 1368/21384
# Downloaded image 1369/21384
# Downloaded image 1370/21384
# Downloaded image 1371/21384
# Downloaded image 1372/21384
# Downloaded image 1373/21384
# Downloaded image 1374/21384
# Downloaded image 1375/21384
# Downloaded image 1376/21384
# Downloaded image 1377/21384
# Downloaded image 1378/21384
# Downloaded image 1379/21384
# Downloaded image 1380/21384
# Downloaded image 1381/21384
# Downloaded image 1382/21384
# Downloaded image 1383/21384
# Downloaded image 1384/21384
# Downloaded image 1385/21384
# Downloaded image 1386/21384
# Downloaded image 1387/21384
# Downloaded image 1388/21384
# Downloaded image 1389/21384
# Downloaded image 1390/21384
# Downloaded image 1391/21384
# Downloaded image 1392/21384
# Downloaded image 1393/21384
# Downloaded image 1394/21384
# Downloaded image 1395/21384
# Downloaded image 1396/21384
# Downloaded image 1397/21384
# Downloaded image 1398/21384
# Downloaded image 1399/21384
# Downloaded image 1400/21384
# Downloaded image 1401/21384
# Downloaded image 1402/21384
# Downloaded image 1403/21384
# Downloaded image 1404/21384
# Downloaded image 1405/21384
# Downloaded image 1406/21384
# Downloaded image 1407/21384
# Downloaded image 1408/21384
# Downloaded image 1409/21384
# Downloaded image 1410/21384
# Downloaded image 1411/21384
# Downloaded image 1412/21384
# Downloaded image 1413/21384
# Downloaded image 1414/21384
# Downloaded image 1415/21384
# Downloaded image 1416/21384
# Downloaded image 1417/21384
# Downloaded image 1418/21384
# Downloaded image 1419/21384
# Downloaded image 1420/21384
# Downloaded image 1421/21384
# Downloaded image 1422/21384
# Downloaded image 1423/21384
# Downloaded image 1424/21384
# Downloaded image 1425/21384
# Downloaded image 1426/21384
# Downloaded image 1427/21384
# Downloaded image 1428/21384
# Downloaded image 1429/21384
# Downloaded image 1430/21384
# Downloaded image 1431/21384
# Downloaded image 1432/21384
# Downloaded image 1433/21384
# Downloaded image 1434/21384
# Downloaded image 1435/21384
# Downloaded image 1436/21384
# Downloaded image 1437/21384
# Downloaded image 1438/21384
# Downloaded image 1439/21384
# Downloaded image 1440/21384
# Downloaded image 1441/21384
# Downloaded image 1442/21384
# Downloaded image 1443/21384
# Downloaded image 1444/21384
# Downloaded image 1445/21384
# Downloaded image 1446/21384
# Downloaded image 1447/21384
# Downloaded image 1448/21384
# Downloaded image 1449/21384
# Downloaded image 1450/21384
# Downloaded image 1451/21384
# Downloaded image 1452/21384
# Downloaded image 1453/21384
# Downloaded image 1454/21384
# Downloaded image 1455/21384
# Downloaded image 1456/21384
# Downloaded image 1457/21384
# Downloaded image 1458/21384
# Downloaded image 1459/21384
# Downloaded image 1460/21384
# Downloaded image 1461/21384
# Downloaded image 1462/21384
# Downloaded image 1463/21384
# Downloaded image 1464/21384
# Downloaded image 1465/21384
# Downloaded image 1466/21384
# Downloaded image 1467/21384
# Downloaded image 1468/21384
# Downloaded image 1469/21384
# Downloaded image 1470/21384
# Downloaded image 1471/21384
# Downloaded image 1472/21384
# Downloaded image 1473/21384
# Downloaded image 1474/21384
# Downloaded image 1475/21384
# Downloaded image 1476/21384
# Downloaded image 1477/21384
# Downloaded image 1478/21384
# Downloaded image 1479/21384
# Downloaded image 1480/21384
# Downloaded image 1481/21384
# Downloaded image 1482/21384
# Downloaded image 1483/21384
# Downloaded image 1484/21384
# Downloaded image 1485/21384
# Downloaded image 1486/21384
# Downloaded image 1487/21384
# Downloaded image 1488/21384
# Downloaded image 1489/21384
# Downloaded image 1490/21384
# Downloaded image 1491/21384
# Downloaded image 1492/21384
# Downloaded image 1493/21384
# Downloaded image 1494/21384
# Downloaded image 1495/21384
# Downloaded image 1496/21384
# Downloaded image 1497/21384
# Downloaded image 1498/21384
# Downloaded image 1499/21384
# Downloaded image 1500/21384
# Downloaded image 1501/21384
# Downloaded image 1502/21384
# Downloaded image 1503/21384
# Downloaded image 1504/21384
# Downloaded image 1505/21384
# Downloaded image 1506/21384
# Downloaded image 1507/21384
# Downloaded image 1508/21384
# Downloaded image 1509/21384
# Downloaded image 1510/21384
# Downloaded image 1511/21384
# Downloaded image 1512/21384
# Downloaded image 1513/21384
# Downloaded image 1514/21384
# Downloaded image 1515/21384
# Downloaded image 1516/21384
# Downloaded image 1517/21384
# Downloaded image 1518/21384
# Downloaded image 1519/21384
# Downloaded image 1520/21384
# Downloaded image 1521/21384
# Downloaded image 1522/21384
# Downloaded image 1523/21384
# Downloaded image 1524/21384
# Downloaded image 1525/21384
# Downloaded image 1526/21384
# Downloaded image 1527/21384
# Downloaded image 1528/21384
# Downloaded image 1529/21384
# Downloaded image 1530/21384
# Downloaded image 1531/21384
# Downloaded image 1532/21384
# Downloaded image 1533/21384
# Downloaded image 1534/21384
# Downloaded image 1535/21384
# Downloaded image 1536/21384
# Downloaded image 1537/21384
# Downloaded image 1538/21384
# Downloaded image 1539/21384
# Downloaded image 1540/21384
# Downloaded image 1541/21384
# Downloaded image 1542/21384
# Downloaded image 1543/21384
# Downloaded image 1544/21384
# Downloaded image 1545/21384
# Downloaded image 1546/21384
# Downloaded image 1547/21384
# Downloaded image 1548/21384
# Downloaded image 1549/21384
# Downloaded image 1550/21384
# Downloaded image 1551/21384
# Downloaded image 1552/21384
# Downloaded image 1553/21384
# Downloaded image 1554/21384
# Downloaded image 1555/21384
# Downloaded image 1556/21384
# Downloaded image 1557/21384
# Downloaded image 1558/21384
# Downloaded image 1559/21384
# Downloaded image 1560/21384
# Downloaded image 1561/21384
# Downloaded image 1562/21384
# Downloaded image 1563/21384
# Downloaded image 1564/21384
# Downloaded image 1565/21384
# Downloaded image 1566/21384
# Downloaded image 1567/21384
# Downloaded image 1568/21384
# Downloaded image 1569/21384
# Downloaded image 1570/21384
# Downloaded image 1571/21384
# Downloaded image 1572/21384
# Downloaded image 1573/21384
# Downloaded image 1574/21384
# Downloaded image 1575/21384
# Downloaded image 1576/21384
# Downloaded image 1577/21384
# Downloaded image 1578/21384
# Downloaded image 1579/21384
# Downloaded image 1580/21384
# Downloaded image 1581/21384
# Downloaded image 1582/21384
# Downloaded image 1583/21384
# Downloaded image 1584/21384
# Downloaded image 1585/21384
# Downloaded image 1586/21384
# Downloaded image 1587/21384
# Downloaded image 1588/21384
# Downloaded image 1589/21384
# Downloaded image 1590/21384
# Downloaded image 1591/21384
# Downloaded image 1592/21384
# Downloaded image 1593/21384
# Downloaded image 1594/21384
# Downloaded image 1595/21384
# Downloaded image 1596/21384
# Downloaded image 1597/21384
# Downloaded image 1598/21384
# Downloaded image 1599/21384
# Downloaded image 1600/21384
# Downloaded image 1601/21384
# Downloaded image 1602/21384
# Downloaded image 1603/21384
# Downloaded image 1604/21384
# Downloaded image 1605/21384
# Downloaded image 1606/21384
# Downloaded image 1607/21384
# Downloaded image 1608/21384
# Downloaded image 1609/21384
# Downloaded image 1610/21384
# Downloaded image 1611/21384
# Downloaded image 1612/21384
# Downloaded image 1613/21384
# Downloaded image 1614/21384
# Downloaded image 1615/21384
# Downloaded image 1616/21384
# Downloaded image 1617/21384
# Downloaded image 1618/21384
# Downloaded image 1619/21384
# Downloaded image 1620/21384
# Downloaded image 1621/21384
# Downloaded image 1622/21384
# Downloaded image 1623/21384
# Downloaded image 1624/21384
# Downloaded image 1625/21384
# Downloaded image 1626/21384
# Downloaded image 1627/21384
# Downloaded image 1628/21384
# Downloaded image 1629/21384
# Downloaded image 1630/21384
# Downloaded image 1631/21384
# Downloaded image 1632/21384
# Downloaded image 1633/21384
# Downloaded image 1634/21384
# Downloaded image 1635/21384
# Downloaded image 1636/21384
# Downloaded image 1637/21384
# Downloaded image 1638/21384
# Downloaded image 1639/21384
# Downloaded image 1640/21384
# Downloaded image 1641/21384
# Downloaded image 1642/21384
# Downloaded image 1643/21384
# Downloaded image 1644/21384
# Downloaded image 1645/21384
# Downloaded image 1646/21384
# Downloaded image 1647/21384
# Downloaded image 1648/21384
# Downloaded image 1649/21384
# Downloaded image 1650/21384
# Downloaded image 1651/21384
# Downloaded image 1652/21384
# Downloaded image 1653/21384
# Downloaded image 1654/21384
# Downloaded image 1655/21384
# Downloaded image 1656/21384
# Downloaded image 1657/21384
# Downloaded image 1658/21384
# Downloaded image 1659/21384
# Downloaded image 1660/21384
# Downloaded image 1661/21384
# Downloaded image 1662/21384
# Downloaded image 1663/21384
# Downloaded image 1664/21384
# Downloaded image 1665/21384
# Downloaded image 1666/21384
# Downloaded image 1667/21384
# Downloaded image 1668/21384
# Downloaded image 1669/21384
# Downloaded image 1670/21384
# Downloaded image 1671/21384
# Downloaded image 1672/21384
# Downloaded image 1673/21384
# Downloaded image 1674/21384
# Downloaded image 1675/21384
# Downloaded image 1676/21384
# Downloaded image 1677/21384
# Downloaded image 1678/21384
# Downloaded image 1679/21384
# Downloaded image 1680/21384
# Downloaded image 1681/21384
# Downloaded image 1682/21384
# Downloaded image 1683/21384
# Downloaded image 1684/21384
# Downloaded image 1685/21384
# Downloaded image 1686/21384
# Downloaded image 1687/21384
# Downloaded image 1688/21384
# Downloaded image 1689/21384
# Downloaded image 1690/21384
# Downloaded image 1691/21384
# Downloaded image 1692/21384
# Downloaded image 1693/21384
# Downloaded image 1694/21384
# Downloaded image 1695/21384
# Downloaded image 1696/21384
# Downloaded image 1697/21384
# Downloaded image 1698/21384
# Downloaded image 1699/21384
# Downloaded image 1700/21384
# Downloaded image 1701/21384
# Downloaded image 1702/21384
# Downloaded image 1703/21384
# Downloaded image 1704/21384
# Downloaded image 1705/21384
# Downloaded image 1706/21384
# Downloaded image 1707/21384
# Downloaded image 1708/21384
# Downloaded image 1709/21384
# Downloaded image 1710/21384
# Downloaded image 1711/21384
# Downloaded image 1712/21384
# Downloaded image 1713/21384
# Downloaded image 1714/21384
# Downloaded image 1715/21384
# Downloaded image 1716/21384
# Downloaded image 1717/21384
# Downloaded image 1718/21384
# Downloaded image 1719/21384
# Downloaded image 1720/21384
# Downloaded image 1721/21384
# Downloaded image 1722/21384
# Downloaded image 1723/21384
# Downloaded image 1724/21384
# Downloaded image 1725/21384
# Downloaded image 1726/21384
# Downloaded image 1727/21384
# ...
# Downloaded image 2431/21384
# Downloaded image 2432/21384
# Downloaded image 2433/21384
# Downloaded image 2434/21384
# Downloaded image 2435/21384
# Downloaded image 2436/21384
# Downloaded image 2437/21384
# Downloaded image 2438/21384
# Downloaded image 2439/21384
# Downloaded image 2440/21384
# Downloaded image 2441/21384
# Downloaded image 2442/21384
# Downloaded image 2443/21384
# Downloaded image 2444/21384
# Downloaded image 2445/21384
# Downloaded image 2446/21384
# Downloaded image 2447/21384
# Downloaded image 2448/21384
# Downloaded image 2449/21384
# Downloaded image 2450/21384
# Downloaded image 2451/21384
# Downloaded image 2452/21384
# Downloaded image 2453/21384
# Downloaded image 2454/21384
# Downloaded image 2455/21384
# Downloaded image 2456/21384
# Downloaded image 2457/21384
# Downloaded image 2458/21384
# Downloaded image 2459/21384
# Downloaded image 2460/21384
# Downloaded image 2461/21384
# Downloaded image 2462/21384
# Downloaded image 2463/21384
# Downloaded image 2464/21384
# Downloaded image 2465/21384
# Downloaded image 2466/21384
# Downloaded image 2467/21384
# Downloaded image 2468/21384
# Downloaded image 2469/21384
# Downloaded image 2470/21384
# Downloaded image 2471/21384
# Downloaded image 2472/21384
# Downloaded image 2473/21384
# Downloaded image 2474/21384
# Downloaded image 2475/21384
# Downloaded image 2476/21384
# Downloaded image 2477/21384
# Downloaded image 2478/21384
# Downloaded image 2479/21384
# Downloaded image 2480/21384
# Downloaded image 2481/21384
# Downloaded image 2482/21384
# Downloaded image 2483/21384
# Downloaded image 2484/21384
# Downloaded image 2485/21384
# Downloaded image 2486/21384
# Downloaded image 2487/21384
# Downloaded image 2488/21384
# Downloaded image 2489/21384
# Downloaded image 2490/21384
# Downloaded image 2491/21384
# Downloaded image 2492/21384
# Downloaded image 2493/21384
# Downloaded image 2494/21384
# Downloaded image 2495/21384
# Downloaded image 2496/21384
# Downloaded image 2497/21384
# Downloaded image 2498/21384
# Downloaded image 2499/21384
# Downloaded image 2500/21384
# Downloaded image 2501/21384
# Downloaded image 2502/21384
# Downloaded image 2503/21384
# Downloaded image 2504/21384
# Downloaded image 2505/21384
# Downloaded image 2506/21384
# Downloaded image 2507/21384
# Downloaded image 2508/21384
# Downloaded image 2509/21384
# Downloaded image 2510/21384
# Downloaded image 2511/21384
# Downloaded image 2512/21384
# Downloaded image 2513/21384
# Downloaded image 2514/21384
# Downloaded image 2515/21384
# Downloaded image 2516/21384
# Downloaded image 2517/21384
# Downloaded image 2518/21384
# Downloaded image 2519/21384
# Downloaded image 2520/21384
# Downloaded image 2521/21384
# Downloaded image 2522/21384
# Downloaded image 2523/21384
# Downloaded image 2524/21384
# Downloaded image 2525/21384
# Downloaded image 2526/21384
# Downloaded image 2527/21384
# Downloaded image 2528/21384
# Downloaded image 2529/21384
# Downloaded image 2530/21384
# Downloaded image 2531/21384
# Downloaded image 2532/21384
# Downloaded image 2533/21384
# Downloaded image 2534/21384
# Downloaded image 2535/21384
# Downloaded image 2536/21384
# Downloaded image 2537/21384
# Downloaded image 2538/21384
# Downloaded image 2539/21384
# Downloaded image 2540/21384
# Downloaded image 2541/21384
# Downloaded image 2542/21384
# Downloaded image 2543/21384
# Downloaded image 2544/21384
# Downloaded image 2545/21384
# Downloaded image 2546/21384
# Downloaded image 2547/21384
# Downloaded image 2548/21384
# Downloaded image 2549/21384
# Downloaded image 2550/21384
# Downloaded image 2551/21384
# Downloaded image 2552/21384
# Downloaded image 2553/21384
# Downloaded image 2554/21384
# Downloaded image 2555/21384
# Downloaded image 2556/21384
# Downloaded image 2557/21384
# Downloaded image 2558/21384
# Downloaded image 2559/21384
# Downloaded image 2560/21384
# Downloaded image 2561/21384
# Downloaded image 2562/21384
# Downloaded image 2563/21384
# Downloaded image 2564/21384
# Downloaded image 2565/21384
# Downloaded image 2566/21384
# Downloaded image 2567/21384
# Downloaded image 2568/21384
# Downloaded image 2569/21384
# Downloaded image 2570/21384
# Downloaded image 2571/21384
# Downloaded image 2572/21384
# Downloaded image 2573/21384
# Downloaded image 2574/21384
# Downloaded image 2575/21384
# Downloaded image 2576/21384
# Downloaded image 2577/21384
# Downloaded image 2578/21384
# Downloaded image 2579/21384
# Downloaded image 2580/21384
# Downloaded image 2581/21384
# Downloaded image 2582/21384
# Downloaded image 2583/21384
# Downloaded image 2584/21384
# Downloaded image 2585/21384
# Downloaded image 2586/21384
# Downloaded image 2587/21384
# Downloaded image 2588/21384
# Downloaded image 2589/21384
# Downloaded image 2590/21384
# Downloaded image 2591/21384
# Downloaded image 2592/21384
# Downloaded image 2593/21384
# Downloaded image 2594/21384
# Downloaded image 2595/21384
# Downloaded image 2596/21384
# Downloaded image 2597/21384
# Downloaded image 2598/21384
# Downloaded image 2599/21384
# Downloaded image 2600/21384
# Downloaded image 2601/21384
# Downloaded image 2602/21384
# Downloaded image 2603/21384
# Downloaded image 2604/21384
# Downloaded image 2605/21384
# Downloaded image 2606/21384
# Downloaded image 2607/21384
# Downloaded image 2608/21384
# Downloaded image 2609/21384
# Downloaded image 2610/21384
# Downloaded image 2611/21384
# Downloaded image 2612/21384
# Downloaded image 2613/21384
# Downloaded image 2614/21384
# Downloaded image 2615/21384
# Downloaded image 2616/21384
# Downloaded image 2617/21384
# Downloaded image 2618/21384
# Downloaded image 2619/21384
# Downloaded image 2620/21384
# Downloaded image 2621/21384
# Downloaded image 2622/21384
# Downloaded image 2623/21384
# Downloaded image 2624/21384
# Downloaded image 2625/21384
# Downloaded image 2626/21384
# Downloaded image 2627/21384
# Downloaded image 2628/21384
# Downloaded image 2629/21384
# Downloaded image 2630/21384
# Downloaded image 2631/21384
# Downloaded image 2632/21384
# Downloaded image 2633/21384
# Downloaded image 2634/21384
# Downloaded image 2635/21384
# Downloaded image 2636/21384
# Downloaded image 2637/21384
# Downloaded image 2638/21384
# Downloaded image 2639/21384
# Downloaded image 2640/21384
# Downloaded image 2641/21384
# Downloaded image 2642/21384
# Downloaded image 2643/21384
# Downloaded image 2644/21384
# Downloaded image 2645/21384
# Downloaded image 2646/21384
# Downloaded image 2647/21384
# Downloaded image 2648/21384
# Downloaded image 2649/21384
# Downloaded image 2650/21384
# Downloaded image 2651/21384
# Downloaded image 2652/21384
# Downloaded image 2653/21384
# Downloaded image 2654/21384
# Downloaded image 2655/21384
# Downloaded image 2656/21384
# Downloaded image 2657/21384
# Downloaded image 2658/21384
# Downloaded image 2659/21384
# Downloaded image 2660/21384
# Downloaded image 2661/21384
# Downloaded image 2662/21384
# Downloaded image 2663/21384
# Downloaded image 2664/21384
# Downloaded image 2665/21384
# Downloaded image 2666/21384
# Downloaded image 2667/21384
# Downloaded image 2668/21384
# Downloaded image 2669/21384
# Downloaded image 2670/21384
# Downloaded image 2671/21384
# Downloaded image 2672/21384
# Downloaded image 2673/21384
# Downloaded image 2674/21384
# Downloaded image 2675/21384
# Downloaded image 2676/21384
# Downloaded image 2677/21384
# Downloaded image 2678/21384
# Downloaded image 2679/21384
# Downloaded image 2680/21384
# Downloaded image 2681/21384
# Downloaded image 2682/21384
# Downloaded image 2683/21384
# Downloaded image 2684/21384
# Downloaded image 2685/21384
# Downloaded image 2686/21384
# Downloaded image 2687/21384
# Downloaded image 2688/21384
# Downloaded image 2689/21384
# Downloaded image 2690/21384
# Downloaded image 2691/21384
# Downloaded image 2692/21384
# Downloaded image 2693/21384
# Downloaded image 2694/21384
# Downloaded image 2695/21384
# Downloaded image 2696/21384
# Downloaded image 2697/21384
# Downloaded image 2698/21384
# Downloaded image 2699/21384
# Downloaded image 2700/21384
# Downloaded image 2701/21384
# Downloaded image 2702/21384
# Downloaded image 2703/21384
# Downloaded image 2704/21384
# Downloaded image 2705/21384
# Downloaded image 2706/21384
# Downloaded image 2707/21384
# Downloaded image 2708/21384
# Downloaded image 2709/21384
# Downloaded image 2710/21384
# Downloaded image 2711/21384
# Downloaded image 2712/21384
# Downloaded image 2713/21384
# Downloaded image 2714/21384
# Downloaded image 2715/21384
# Downloaded image 2716/21384
# Downloaded image 2717/21384
# Downloaded image 2718/21384
# Downloaded image 2719/21384
# Downloaded image 2720/21384
# Downloaded image 2721/21384
# Downloaded image 2722/21384
# Downloaded image 2723/21384
# Downloaded image 2724/21384
# Downloaded image 2725/21384
# Downloaded image 2726/21384
# Downloaded image 2727/21384
# Downloaded image 2728/21384
# Downloaded image 2729/21384
# Downloaded image 2730/21384
# Downloaded image 2731/21384
# Downloaded image 2732/21384
# Downloaded image 2733/21384
# Downloaded image 2734/21384
# Downloaded image 2735/21384
# Downloaded image 2736/21384
# Downloaded image 2737/21384
# Downloaded image 2738/21384
# Downloaded image 2739/21384
# Downloaded image 2740/21384
# Downloaded image 2741/21384
# Downloaded image 2742/21384
# Downloaded image 2743/21384
# Downloaded image 2744/21384
# Downloaded image 2745/21384
# Downloaded image 2746/21384
# Downloaded image 2747/21384
# Downloaded image 2748/21384
# Downloaded image 2749/21384
# Downloaded image 2750/21384
# Downloaded image 2751/21384
# Downloaded image 2752/21384
# Downloaded image 2753/21384
# Downloaded image 2754/21384
# Downloaded image 2755/21384
# Downloaded image 2756/21384
# Downloaded image 2757/21384
# Downloaded image 2758/21384
# Downloaded image 2759/21384
# Downloaded image 2760/21384
# Downloaded image 2761/21384
# Downloaded image 2762/21384
# Downloaded image 2763/21384
# Downloaded image 2764/21384
# Downloaded image 2765/21384
# Downloaded image 2766/21384
# Downloaded image 2767/21384
# Downloaded image 2768/21384
# Downloaded image 2769/21384
# Downloaded image 2770/21384
# Downloaded image 2771/21384
# Downloaded image 2772/21384
# Downloaded image 2773/21384
# Downloaded image 2774/21384
# Downloaded image 2775/21384
# Downloaded image 2776/21384
# Downloaded image 2777/21384
# Downloaded image 2778/21384
# Downloaded image 2779/21384
# Downloaded image 2780/21384
# Downloaded image 2781/21384
# Downloaded image 2782/21384
# Downloaded image 2783/21384
# Downloaded image 2784/21384
# Downloaded image 2785/21384
# Downloaded image 2786/21384
# Downloaded image 2787/21384
# Downloaded image 2788/21384
# Downloaded image 2789/21384
# Downloaded image 2790/21384
# Downloaded image 2791/21384
# Downloaded image 2792/21384
# Downloaded image 2793/21384
# Downloaded image 2794/21384
# Downloaded image 2795/21384
# Downloaded image 2796/21384
# Downloaded image 2797/21384
# Downloaded image 2798/21384
# Downloaded image 2799/21384
# Downloaded image 2800/21384
# Downloaded image 2801/21384
# Downloaded image 2802/21384
# Downloaded image 2803/21384
# Downloaded image 2804/21384
# Downloaded image 2805/21384
# Downloaded image 2806/21384
# Downloaded image 2807/21384
# Downloaded image 2808/21384
# Downloaded image 2809/21384
# Downloaded image 2810/21384
# Downloaded image 2811/21384
# Downloaded image 2812/21384
# Downloaded image 2813/21384
# Downloaded image 2814/21384
# Downloaded image 2815/21384
# Downloaded image 2816/21384
# Downloaded image 2817/21384
# Downloaded image 2818/21384
# Downloaded image 2819/21384
# Downloaded image 2820/21384
# Downloaded image 2821/21384
# Downloaded image 2822/21384
# Downloaded image 2823/21384
# Downloaded image 2824/21384
# Downloaded image 2825/21384
# Downloaded image 2826/21384
# Downloaded image 2827/21384
# Downloaded image 2828/21384
# Downloaded image 2829/21384
# Downloaded image 2830/21384
# Downloaded image 2831/21384
# Downloaded image 2832/21384
# Downloaded image 2833/21384
# Downloaded image 2834/21384
# Downloaded image 2835/21384
# Downloaded image 2836/21384
# Downloaded image 2837/21384
# Downloaded image 2838/21384
# Downloaded image 2839/21384
# Downloaded image 2840/21384
# Downloaded image 2841/21384
# Downloaded image 2842/21384
# Downloaded image 2843/21384
# Downloaded image 2844/21384
# Downloaded image 2845/21384
# Downloaded image 2846/21384
# Downloaded image 2847/21384
# Downloaded image 2848/21384
# Downloaded image 2849/21384
# Downloaded image 2850/21384
# Downloaded image 2851/21384
# Downloaded image 2852/21384
# Downloaded image 2853/21384
# Downloaded image 2854/21384
# Downloaded image 2855/21384
# Downloaded image 2856/21384
# Downloaded image 2857/21384
# Downloaded image 2858/21384
# Downloaded image 2859/21384
# Downloaded image 2860/21384
# Downloaded image 2861/21384
# Downloaded image 2862/21384
# Downloaded image 2863/21384
# Downloaded image 2864/21384
# Downloaded image 2865/21384
# Downloaded image 2866/21384
# Downloaded image 2867/21384
# Downloaded image 2868/21384
# Downloaded image 2869/21384
# Downloaded image 2870/21384
# Downloaded image 2871/21384
# Downloaded image 2872/21384
# Downloaded image 2873/21384
# Downloaded image 2874/21384
# Downloaded image 2875/21384
# Downloaded image 2876/21384
# Downloaded image 2877/21384
# Downloaded image 2878/21384
# Downloaded image 2879/21384
# Downloaded image 2880/21384
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/geemap/common.py in tms_to_geotiff(output, bbox, zoom, resolution, source, crs, to_cog, quiet, **kwargs)
#   14828     try:
# > 14829         draw_tile(source, south, west, north, east, zoom, output, quiet, **kwargs)
#   14830         if crs.upper() != "EPSG:3857":
#
# /usr/local/lib/python3.11/dist-packages/geemap/common.py in draw_tile(source, lat0, lon0, lat1, lon1, zoom, filename, quiet, **kwargs)
#   14784             for k, (fut, corner_xy) in enumerate(zip(futures, corners), 1):
# > 14785                 bigim = paste_tile(bigim, base_size, fut.result(), corner_xy, bbox)
#   14786                 if not quiet:
#
# /usr/lib/python3.11/concurrent/futures/_base.py in result(self, timeout)
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#
# /usr/lib/python3.11/concurrent/futures/_base.py in __get_result(self)
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#
# /usr/lib/python3.11/concurrent/futures/thread.py in run(self)
#      57         try:
# ---> 58             result = self.fn(*self.args, **self.kwargs)
#      59         except BaseException as exc:
#
# /usr/local/lib/python3.11/dist-packages/geemap/common.py in get_tile(url)
#   14757             return None
# > 14758         r.raise_for_status()
#   14759         return r.content
#
# /usr/local/lib/python3.11/dist-packages/httpx/_models.py in raise_for_status(self)
#     828         message = message.format(self, error_type=error_type)
# --> 829         raise HTTPStatusError(message, request=request, response=self)
#     830
#
# HTTPStatusError: Server error '503 Service Unavailable' for url 'https://earthengine.googleapis.com/v1/projects/ee-praveenpankaj/maps/5b9c91e7300f6e76f5ceeeee27358ce5-535bcecf0b531542b0acca9cc9646db7/tiles/17/22307/52328'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/503
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-138-cd2e86b88797> in <cell line: 0>()
# ----> 1 geemap.ee_to_geotiff(
#       2     se2_ab, "swir.tif", bbox, zoom=17, vis_params={"bands": ['B12', 'B8A', 'B4']}
#       3     )
#
# /usr/local/lib/python3.11/dist-packages/geemap/common.py in ee_to_geotiff(ee_object, output, bbox, vis_params, zoom, resolution, crs, to_cog, quiet, **kwargs)
#   14959         raise ValueError("Either zoom level or resolution must be specified.")
#   14960
# > 14961     tms_to_geotiff(output, bbox, zoom, resolution, url, crs, to_cog, quiet, **kwargs)
#   14962
#   14963
#
# /usr/local/lib/python3.11/dist-packages/geemap/common.py in tms_to_geotiff(output, bbox, zoom, resolution, source, crs, to_cog, quiet, **kwargs)
#   14833             image_to_cog(output, output)
#   14834     except Exception as e:
# > 14835         raise Exception(e)
#   14836
#   14837
#
# Exception: Server error '503 Service Unavailable' for url 'https://earthengine.googleapis.com/v1/projects/ee-praveenpankaj/maps/5b9c91e7300f6e76f5ceeeee27358ce5-535bcecf0b531542b0acca9cc9646db7/tiles/17/22307/52328'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/503

# %%
sam = SamGeo(
    model_type="vit_h",
    checkpoint="sam_vit_h_4b8939.pth",
    device=None,
    sam_kwargs=None,
)

# %%
sam.generate("swir.tif", output="masks.tif", foreground=True, unique=True)

# %%
sam.show_masks(cmap="binary_r")

# %%
sam.show_anns(axis="off", alpha=1, output="annotations.tif")
